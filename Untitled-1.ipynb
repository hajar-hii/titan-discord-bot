# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import neattext.functions as nfx

# %%
df=pd.read_csv("emotions1.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Emotion                                               Text  \
# 0           0  neutral                                             Why ?
# 1           1      joy    Sage Act upgrade on my to do list for tommorow.
# 2           2  sadness  ON THE WAY TO MY HOMEGIRL BABY FUNERAL!!! MAN ...
# 3           3      joy   Such an eye ! The true hazel eye-and so brill...
# 4           4      joy  @Iluvmiasantos ugh babe.. hugggzzz for u .!  b...
#
#                                           Clean_Text
# 0                                                NaN
# 1                     Sage Act upgrade list tommorow
# 2  WAY HOMEGIRL BABY FUNERAL MAN HATE FUNERALS SH...
# 3  eye  true hazel eyeand brilliant  Regular feat...
# 4    ugh babe hugggzzz u  babe naamazed nga ako e...

# %%
df.shape
# Out:
# (20379, 4)

# %%
df.dtypes
# Out:
# Unnamed: 0     int64
# Emotion       object
# Text          object
# Clean_Text    object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Emotion         0
# Text            0
# Clean_Text    279
# dtype: int64

# %%
df['Emotion'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
plt.figure(figsize=(20,10))
sns.countplot(x='Emotion',data=df)
plt.show()

# %%
pip install TextBlob
# Out:
# Collecting TextBlobNote: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Downloading textblob-0.17.1-py2.py3-none-any.whl (636 kB)
#      ------------------------------------ 636.8/636.8 kB 445.6 kB/s eta 0:00:00
# Collecting nltk>=3.1
#   Downloading nltk-3.8-py3-none-any.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 442.3 kB/s eta 0:00:00
# Collecting tqdm
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.5/78.5 kB 1.1 MB/s eta 0:00:00
# Collecting joblib
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      ------------------------------------ 298.0/298.0 kB 460.4 kB/s eta 0:00:00
# Collecting regex>=2021.8.3
#   Downloading regex-2022.10.31-cp310-cp310-win_amd64.whl (267 kB)
#      ------------------------------------ 267.7/267.7 kB 411.9 kB/s eta 0:00:00
# Collecting click
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ---------------------------------------- 96.6/96.6 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\saniya t sandeep\appdata\roaming\python\python310\site-packages (from click->nltk>=3.1->TextBlob) (0.4.6)
# Installing collected packages: tqdm, regex, joblib, click, nltk, TextBlob
# Successfully installed TextBlob-0.17.1 click-8.1.3 joblib-1.2.0 nltk-3.8 regex-2022.10.31 tqdm-4.64.1

# %%
#sentiment analysis
from textblob import TextBlob

# %%
def get_sentiment(text):
    blob=TextBlob(text)
    sentiment=blob.sentiment.polarity
    if sentiment>0:
        result="Positive"
    elif sentiment<0:
        result="Negative"
    else:
        result="Neutral"
    return result

# %%
get_sentiment("i think about coding")
# Out:
# 'Neutral'

# %%
df["Sentiment"]=df['Text'].apply(get_sentiment)

# %%
df.head()
# Out:
#    Unnamed: 0  Emotion                                               Text  \
# 0           0  neutral                                             Why ?
# 1           1      joy    Sage Act upgrade on my to do list for tommorow.
# 2           2  sadness  ON THE WAY TO MY HOMEGIRL BABY FUNERAL!!! MAN ...
# 3           3      joy   Such an eye ! The true hazel eye-and so brill...
# 4           4      joy  @Iluvmiasantos ugh babe.. hugggzzz for u .!  b...
#
#                                           Clean_Text Sentiment
# 0                                                NaN   Neutral
# 1                     Sage Act upgrade list tommorow   Neutral
# 2  WAY HOMEGIRL BABY FUNERAL MAN HATE FUNERALS SH...  Negative
# 3  eye  true hazel eyeand brilliant  Regular feat...  Positive
# 4    ugh babe hugggzzz u  babe naamazed nga ako e...   Neutral
